# %%
# %cd C://Users//ksh//Desktop//workstation//teamplay//yolov5-custom
# Out:
# C:\Users\ksh\Desktop\workstation\teamplay\yolov5-master

# %%
# !python C://Users//ksh//Desktop//workstation//teamplay//yolov5-custom//export.py --weights best.pt --include tflite
# export.py 를 통해 pt file -> tflite 파일로 변환 Defalut값 fp16
# Out:
# ^C
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(1, 640, 640, 3)]   0           []
#
#  tf_conv (TFConv)               (1, 320, 320, 48)    5232        ['input_1[0][0]']
#
#  tf_conv_1 (TFConv)             (1, 160, 160, 96)    41568       ['tf_conv[0][0]']
#
#  tfc3 (TFC3)                    (1, 160, 160, 96)    64896       ['tf_conv_1[0][0]']
#
#  tf_conv_9 (TFConv)             (1, 80, 80, 192)     166080      ['tfc3[0][0]']
#
#  tfc3_1 (TFC3)                  (1, 80, 80, 192)     443520      ['tf_conv_9[0][0]']
#
#  tf_conv_21 (TFConv)            (1, 40, 40, 384)     663936      ['tfc3_1[0][0]']
#
#  tfc3_2 (TFC3)                  (1, 40, 40, 384)     2509824     ['tf_conv_21[0][0]']
#
#  tf_conv_37 (TFConv)            (1, 20, 20, 768)     2654976     ['tfc3_2[0][0]']
#
# ...

# %%
# !python C://Users//ksh//Desktop//workstation//teamplay//yolov5-master//export.py --weights C://Users//ksh//Desktop//workstation//teamplay//yolov5-master//best.pt 
# onnx 파일로 변환
# 초기에는 onnx -> ncnnx-> pb -> tflite 로 변환생각 .
# Out:
# export: data=C:\Users\ksh\Desktop\workstation\teamplay\yolov5-master\data\coco128.yaml, weights=['C://Users//ksh//Desktop//workstation//teamplay//yolov5-master//best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5  2022-5-13 torch 1.11.0+cpu CPU
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 20881221 parameters, 0 gradients
#
# PyTorch: starting from C:\Users\ksh\Desktop\workstation\teamplay\yolov5-master\best.pt with output shape (1, 25200, 13) (160.3 MB)
#
# TorchScript: starting export with torch 1.11.0+cpu...
# TorchScript: export success, saved as C:\Users\ksh\Desktop\workstation\teamplay\yolov5-master\best.torchscript (80.2 MB)
# ...
